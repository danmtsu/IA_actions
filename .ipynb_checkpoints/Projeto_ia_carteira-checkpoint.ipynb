# %% [markdown]
# # Projeto Ciencia de Dados: Carteira de Ações com Inteligência Artificial
#
# - Projeto Inspiração: https://medium.com/swlh/teaching-a-machine-to-trade-stocks-like-warren-buffett-part-i-445849b208c6
# - Resumo Fundamentos Empresas BR: https://fundamentus.com.br/index.php

# %% [markdown]
# ### Criar Dicionários de Dataframes com cada empresa

# %%
import pandas as pd
import os

# Lista de empresas
empresas = ["ABEV3", "AZUL4", "BTOW3", "B3SA3", "BBSE3", "BRML3", "BBDC4", "BRAP4", "BBAS3", "BRKM5", 
            "BRFS3", "BPAC11", "CRFB3", "CCRO3", "CMIG4", "HGTX3", "CIEL3", "COGN3", "CPLE6", "CSAN3", 
            "CPFE3", "CVCB3", "CYRE3", "ECOR3", "ELET6", "EMBR3", "ENBR3", "ENGI11", "ENEV3", "EGIE3", 
            "EQTL3", "EZTC3", "FLRY3", "GGBR4", "GOAU4", "GOLL4", "NTCO3", "HAPV3", "HYPE3", "IGTA3", 
            "GNDI3", "ITSA4", "ITUB4", "JBSS3", "JHSF3", "KLBN11", "RENT3", "LCAM3", "LAME4", "LREN3", 
            "MGLU3", "MRFG3", "BEEF3", "MRVE3", "MULT3", "PCAR3", "PETR4", "BRDT3", "PRIO3", "QUAL3", 
            "RADL3", "RAIL3", "SBSP3", "SANB11", "CSNA3", "SULA11", "SUZB3", "TAEE11", "VIVT3", "TIMS3", 
            "TOTS3", "UGPA3", "USIM5", "VALE3", "VVAR3", "WEGE3", "YDUQ3"]

# Dicionário para armazenar os dados
fundamentos = {}

# Diretório dos arquivos
diretorio = "IA_Carteira45Z/balancos-20240720T050244Z-001/balancos"

# Listar os arquivos no diretório
arquivos = os.listdir(diretorio)

# Loop através dos arquivos
for arquivo in arquivos:
    # Extrair o nome do arquivo
    nome = arquivo[-9:-4]
    if "11" in nome:
        nome = arquivo[-10:-4]
    
    # Verificar se o nome está na lista de empresas
    if nome in empresas:
        print(nome)
        # Construir o caminho completo para o arquivo
        caminho_arquivo = os.path.join(diretorio, arquivo)

        # Ler os dados dos arquivos Excel
        balanco = pd.read_excel(caminho_arquivo, sheet_name=0, engine='xlrd')
        dre = pd.read_excel(caminho_arquivo, sheet_name=1, engine='xlrd')

        # Manipulação dos DataFrames
        balanco.iloc[0, 0] = nome
        balanco.columns = balanco.iloc[0]
        balanco = balanco[1:]
        balanco = balanco.set_index(nome)
        
        dre.iloc[0, 0] = nome
        dre.columns = dre.iloc[0]
        dre = dre[1:]
        dre = dre.set_index(nome)

        # Adicionar ao dicionário fundamentos
        fundamentos[nome] = pd.concat([balanco, dre])

# Exibir o resultado
for empresa, dados in fundamentos.items():
    print(f"Empresa: {empresa}")
    display(dados)
# Out:
# VALE3
# WARNING *** file size (64278) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64278) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# NTCO3
# WARNING *** file size (15892) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (15892) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ABEV3
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# B3SA3
# WARNING *** file size (64274) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64274) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# BBAS3
# WARNING *** file size (68412) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (68412) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# BPAC11
# WARNING *** file size (66667) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (66667) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# BRDT3
# WARNING *** file size (30325) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (30325) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WEGE3
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# MRFG3
# WARNING *** file size (64284) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64284) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# CVCB3
# WARNING *** file size (50451) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (50451) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# SBSP3
# WARNING *** file size (63832) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (63832) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# USIM5
# WARNING *** file size (64286) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64286) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# EMBR3
# WARNING *** file size (64284) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64284) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# CSAN3
# WARNING *** file size (64107) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64107) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# HAPV3
# WARNING *** file size (24947) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (24947) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# CPFE3
# WARNING *** file size (64412) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64412) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# GOLL4
# WARNING *** file size (64336) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64336) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# GNDI3
# WARNING *** file size (24955) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (24955) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# BRAP4
# WARNING *** file size (64404) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64404) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# IGTA3
# WARNING *** file size (64286) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64286) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# EGIE3
# WARNING *** file size (64296) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64296) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# BRML3
# WARNING *** file size (64322) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64322) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# PRIO3
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ITUB4
# WARNING *** file size (68522) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (68522) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# MGLU3
# WARNING *** file size (62531) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (62531) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# RAIL3
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# SUZB3
# WARNING *** file size (64294) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64294) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ECOR3
# WARNING *** file size (64292) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64292) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# SULA11
# WARNING *** file size (64292) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64292) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# AZUL4
# WARNING *** file size (30309) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (30309) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# CYRE3
# WARNING *** file size (64310) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64310) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# EQTL3
# WARNING *** file size (64424) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64424) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ITSA4
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# GGBR4
# WARNING *** file size (64256) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64256) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ENBR3
# WARNING *** file size (64322) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64322) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# RADL3
# WARNING *** file size (64060) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64060) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# MRVE3
# WARNING *** file size (64276) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64276) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# FLRY3
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# CCRO3
# WARNING *** file size (64340) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64340) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# BRFS3
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# COGN3
# WARNING *** file size (64388) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64388) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# TIMS3
# WARNING *** file size (19427) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (19427) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# RENT3
# WARNING *** file size (64308) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64308) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# JBSS3
# WARNING *** file size (64330) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64330) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ENEV3
# WARNING *** file size (64280) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64280) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# BTOW3
# WARNING *** file size (64334) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64334) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# VVAR3
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# EZTC3
# WARNING *** file size (64280) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64280) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# BBSE3
# WARNING *** file size (16355) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (16355) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# CPLE6
# WARNING *** file size (64280) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64280) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# CRFB3
# WARNING *** file size (30325) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (30325) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ENGI11
# WARNING *** file size (64286) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64286) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# TOTS3
# WARNING *** file size (64280) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64280) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# YDUQ3
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# PCAR3
# WARNING *** file size (64296) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64296) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# CSNA3
# WARNING *** file size (64276) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64276) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# UGPA3
# WARNING *** file size (64320) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64320) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# LAME4
# WARNING *** file size (64312) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64312) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# BEEF3
# WARNING *** file size (64284) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64284) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# HYPE3
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# ELET6
# WARNING *** file size (64398) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64398) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# SANB11
# WARNING *** file size (68210) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (68210) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# GOAU4
# WARNING *** file size (64270) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64270) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# CMIG4
# WARNING *** file size (64388) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64388) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# HGTX3
# WARNING *** file size (64290) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64290) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# KLBN11
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# JHSF3
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# LCAM3
# WARNING *** file size (62367) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (62367) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# CIEL3
# WARNING *** file size (64136) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64136) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# TAEE11
# WARNING *** file size (64280) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64280) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# BBDC4
# WARNING *** file size (68284) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (68284) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# PETR4
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# VIVT3
# WARNING *** file size (64294) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64294) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# BRKM5
# WARNING *** file size (64284) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64284) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# LREN3
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64282) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# QUAL3
# WARNING *** file size (61185) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (61185) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# MULT3
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** file size (64288) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Empresa: VALE3
# 0                                            31/12/2020     30/09/2020  \
# VALE3
# Ativo Total                               478129487.872  451139567.616
# Ativo Circulante                          126805172.224   98957139.968
# Caixa e Equivalentes de Caixa              70085566.464   49889390.592
# Aplicações Financeiras                                0              0
# Contas a Receber                            27233884.16   18736359.424
# ...                                                 ...            ...
# IR Diferido                                 9461866.496        -240184
# Participações/Contribuições Estatutárias            NaN            NaN
# Reversão dos Juros sobre Capital Próprio            NaN            NaN
# Part. de Acionistas Não Controladores        508776.992     542868.992
# Lucro/Prejuízo do Período                   4824832.512    15615098.88
#
# 0                                            30/06/2020     31/03/2020  \
# VALE3
# Ativo Total                                455303495.68  439707009.024
# Ativo Circulante                          111195316.224    103682252.8
# Caixa e Equivalentes de Caixa               66333143.04   61284200.448
# Aplicações Financeiras                                0              0
# Contas a Receber                           15867577.344   12314358.784
# ...                                                 ...            ...
# IR Diferido                                  886881.024    4694800.896
# Participações/Contribuições Estatutárias            NaN            NaN
# Reversão dos Juros sobre Capital Próprio            NaN            NaN
# Part. de Acionistas Não Controladores        411288.992     347436.992
# Lucro/Prejuízo do Período                   5288399.872     984380.032
#
# 0                                            31/12/2019     30/09/2019  \
# VALE3
# Ativo Total                               369670324.224  391021101.056
# Ativo Circulante                           68697542.656    76985671.68
# Caixa e Equivalentes de Caixa              29627092.992    35644436.48
# Aplicações Financeiras                                0              0
# Contas a Receber                           11483278.336    10764047.36
# ...                                                 ...            ...
# IR Diferido                                 6005999.104    -485324.992
# Participações/Contribuições Estatutárias            NaN            NaN
# Reversão dos Juros sobre Capital Próprio            NaN            NaN
# Part. de Acionistas Não Controladores       1785862.912          80367
# Lucro/Prejuízo do Período                  -6406967.808      6541644.8
#
# 0                                           30/06/2019     31/03/2019  \
# VALE3
# Ativo Total                               366869544.96  366875541.504
# Ativo Circulante                          60989087.744   58742235.136
# Caixa e Equivalentes de Caixa             23176175.616    19512944.64
# Aplicações Financeiras                               0              0
# Contas a Receber                          12692306.944   10729877.504
# ...                                                ...            ...
# IR Diferido                                    -431576    3405063.936
# Participações/Contribuições Estatutárias           NaN            NaN
# Reversão dos Juros sobre Capital Próprio           NaN            NaN
# Part. de Acionistas Não Controladores            34715         123650
# Lucro/Prejuízo do Período                      -384156   -6421965.824
#
# 0                                           31/12/2018     30/09/2018  ...  \
# VALE3                                                                  ...
# Ativo Total                               341714862.08  342278569.984  ...
# Ativo Circulante                            59256115.2   60585832.448  ...
# Caixa e Equivalentes de Caixa             22412548.096   24424372.224  ...
# Aplicações Financeiras                               0              0  ...
# Contas a Receber                          11669972.992   11150082.048  ...
# ...                                                ...            ...  ...
# IR Diferido                                5793426.944   -2730781.952  ...
# Participações/Contribuições Estatutárias           NaN            NaN  ...
# Reversão dos Juros sobre Capital Próprio           NaN            NaN  ...
# Part. de Acionistas Não Controladores      -175360.992         145388  ...
# Lucro/Prejuízo do Período                  14485278.72     5753041.92  ...
#
# 0                                            31/12/2012     30/09/2012  \
# VALE3
# Ativo Total                               266921639.936  272265084.928
# Ativo Circulante                           46039617.536   50607919.104
# Caixa e Equivalentes de Caixa              11917717.504   16105086.976
# Aplicações Financeiras                                0    1387282.944
# Contas a Receber                           14670865.408   14020866.048
# ...                                                 ...            ...
# IR Diferido                                -4229620.736    1438023.936
# Participações/Contribuições Estatutárias            NaN            NaN
# Reversão dos Juros sobre Capital Próprio            NaN            NaN
# Part. de Acionistas Não Controladores         98453.984         165836
# Lucro/Prejuízo do Período                  -5628453.376    3328082.944
#
# 0                                           30/06/2012     31/03/2012  \
# VALE3
# Ativo Total                               253501358.08  242568101.888
# Ativo Circulante                          41205526.528   40794046.464
# Caixa e Equivalentes de Caixa              8117668.864     9010805.76
# Aplicações Financeiras                               0              0
# Contas a Receber                          14670203.904   14324738.048
# ...                                                ...            ...
# IR Diferido                                2286459.904     505136.992
# Participações/Contribuições Estatutárias           NaN            NaN
# Reversão dos Juros sobre Capital Próprio           NaN            NaN
# Part. de Acionistas Não Controladores           133401         103071
# Lucro/Prejuízo do Período                  5313666.048    6720399.872
#
# 0                                           31/12/2011     30/09/2011  \
# VALE3
# Ativo Total                               241783111.68  239097331.712
# Ativo Circulante                          42095214.592     50422067.2
# Caixa e Equivalentes de Caixa              7457928.192    14674488.32
# Aplicações Financeiras                               0              0
# Contas a Receber                          16304722.944   16645069.824
# ...                                                ...            ...
# IR Diferido                                -358537.088    1497244.032
# Participações/Contribuições Estatutárias           NaN            NaN
# Reversão dos Juros sobre Capital Próprio           NaN            NaN
# Part. de Acionistas Não Controladores       185203.008          42892
# Lucro/Prejuízo do Período                    8354444.8    7892936.192
#
# 0                                           30/06/2011     31/03/2011  \
# VALE3
# Ativo Total                               222235607.04  217320210.432
# Ativo Circulante                          50617757.696   46568992.768
# Caixa e Equivalentes de Caixa             21323360.256   19138881.536
# Aplicações Financeiras                               0              0
# Contas a Receber                          13350412.288   12815632.384
# ...                                                ...            ...
# IR Diferido                               -1138706.944              0
# Participações/Contribuições Estatutárias           NaN            NaN
# Reversão dos Juros sobre Capital Próprio           NaN            NaN
# Part. de Acionistas Não Controladores            95308          90096
# Lucro/Prejuízo do Período                  10275358.72   11290983.424
#
# 0                                            31/12/2010    30/09/2010
# VALE3
# Ativo Total                               214662119.424  209939415.04
# Ativo Circulante                           54267830.272  54095454.208
# Caixa e Equivalentes de Caixa              13468957.696  16949476.352
# Aplicações Financeiras                                0             0
# Contas a Receber                           14052471.808   13344035.84
# ...                                                 ...           ...
# IR Diferido                                           0             0
# Participações/Contribuições Estatutárias            NaN             0
# Reversão dos Juros sobre Capital Próprio            NaN             0
# Part. de Acionistas Não Controladores       -208342.992       -114345
# Lucro/Prejuízo do Período                   10002237.44  10553688.064
#
# [79 rows x 42 columns]
# Empresa: NTCO3
# 0                                           31/12/2020    30/09/2020  \
# NTCO3
# Ativo Total                                60917596.16  64320626.688
# Ativo Circulante                          18734819.328   19099330.56
# Caixa e Equivalentes de Caixa              5821671.936    5059868.16
# Aplicações Financeiras                     2520647.936   2890974.976
# Contas a Receber                           3597534.976   3617396.992
# ...                                                ...           ...
# IR Diferido                                          0             0
# Participações/Contribuições Estatutárias           NaN           NaN
# Reversão dos Juros sobre Capital Próprio           NaN           NaN
# Part. de Acionistas Não Controladores             1732          4024
# Lucro/Prejuízo do Período                   177394.048    381705.984
#
# 0                                           30/06/2020    31/03/2020  \
# NTCO3
# Ativo Total                               61092921.344  56058740.736
# Ativo Circulante                          17064523.776  13860739.072
# Caixa e Equivalentes de Caixa              4820115.968   3111495.936
# Aplicações Financeiras                     2570203.904    1454807.04
# Contas a Receber                           2644601.088   2774631.936
# ...                                                ...           ...
# IR Diferido                                          0             0
# Participações/Contribuições Estatutárias           NaN           NaN
# Reversão dos Juros sobre Capital Próprio           NaN           NaN
# Part. de Acionistas Não Controladores             3584          4142
# Lucro/Prejuízo do Período                  -388499.008   -820796.992
#
# 0                                          31/12/2019 30/09/2019
# NTCO3
# Ativo Total                                  21184512      1.104
# Ativo Circulante                           9430056.96      1.104
# Caixa e Equivalentes de Caixa              4513582.08      1.104
# Aplicações Financeiras                    1025844.992          0
# Contas a Receber                          1685763.968          0
# ...                                               ...        ...
# IR Diferido                                         0          0
# Participações/Contribuições Estatutárias          NaN        NaN
# Reversão dos Juros sobre Capital Próprio          NaN        NaN
# Part. de Acionistas Não Controladores               0          0
# Lucro/Prejuízo do Período                  155467.008          0
#
# [79 rows x 6 columns]
# Empresa: ABEV3
# 0                                           31/12/2020     30/09/2020  \
# ABEV3
# Ativo Total                               125196574.72  127056781.312
# Ativo Circulante                          35342614.528   39098793.984
# Caixa e Equivalentes de Caixa             17090335.744   21660450.816
# Aplicações Financeiras                     1700028.032    1442923.008
# Contas a Receber                           4303137.792     4156922.88
# ...                                                ...            ...
# IR Diferido                               -1667579.008         343476
# Participações/Contribuições Estatutárias           NaN            NaN
# Reversão dos Juros sobre Capital Próprio           NaN            NaN
# Part. de Acionistas Não Controladores      -104363.008         -84167
# Lucro/Prejuízo do Período                    6786009.6    2274800.896
#
# 0                                            30/06/2020     31/03/2020  \
# ABEV3
# Ativo Total                               121393004.544  113687560.192
# Ativo Circulante                           36268126.208    31086356.48
# Caixa e Equivalentes de Caixa              17438951.424   13204471.808
# Aplicações Financeiras                            44823          44823
# Contas a Receber                            4201583.104    3394298.112
# ...                                                 ...            ...
# IR Diferido                                      595088          15365
# Participações/Contribuições Estatutárias            NaN            NaN
# Reversão dos Juros sobre Capital Próprio            NaN            NaN
# Part. de Acionistas Não Controladores            -44517        -119468
# Lucro/Prejuízo do Período                   1226798.976    1091783.936
#
# 0                                            31/12/2019     30/09/2019  \
# ABEV3
# Ativo Total                               101742944.256  102475317.248
# Ativo Circulante                           27621136.384   29004025.856
# Caixa e Equivalentes de Caixa              11900665.856    15016913.92
# Aplicações Financeiras                            14558          14304
# Contas a Receber                            4495524.864    4236257.024
# ...                                                 ...            ...
# IR Diferido                                 -853995.008     427238.016
# Participações/Contribuições Estatutárias            NaN            NaN
# Reversão dos Juros sobre Capital Próprio            NaN            NaN
# Part. de Acionistas Não Controladores       -119273.008        -106708
# Lucro/Prejuízo do Período                   4099704.832    2497677.056
#
# 0                                           30/06/2019    31/03/2019  \
# ABEV3
# Ativo Total                               98738978.816  96905535.488
# Ativo Circulante                          27356035.072  26194137.088
# Caixa e Equivalentes de Caixa             14233403.392  12822524.928
# Aplicações Financeiras                           14038         13772
# Contas a Receber                            4103118.08   3980359.936
# ...                                                ...           ...
# IR Diferido                                 443414.016        346724
# Participações/Contribuições Estatutárias           NaN           NaN
# Reversão dos Juros sobre Capital Próprio           NaN           NaN
# Part. de Acionistas Não Controladores           -95168        -87218
# Lucro/Prejuízo do Período                  2520732.928   2661850.112
#
# 0                                           31/12/2018    30/09/2018  ...  \
# ABEV3                                                                 ...
# Ativo Total                               94126137.344   95691038.72  ...
# Ativo Circulante                          25329604.608  26200020.992  ...
# Caixa e Equivalentes de Caixa             11463497.728  12227668.992  ...
# Aplicações Financeiras                           13391         13008  ...
# Contas a Receber                           4879256.064   4285633.024  ...
# ...                                                ...           ...  ...
# IR Diferido                               -1160932.992    612889.984  ...
# Participações/Contribuições Estatutárias           NaN           NaN  ...
# Reversão dos Juros sobre Capital Próprio           NaN           NaN  ...
# Part. de Acionistas Não Controladores      -103125.992        -60947  ...
# Lucro/Prejuízo do Período                  3360404.736    2831159.04  ...
#
# 0                                           31/03/2015    31/12/2014  \
# ABEV3
# Ativo Total                                   75101184  72143200.256
# Ativo Circulante                          19241015.296  20728420.352
# Caixa e Equivalentes de Caixa              6974584.832   9722066.944
# Aplicações Financeiras                     1033758.016    712958.016
# Contas a Receber                           2897700.096   3028854.016
# ...                                                ...           ...
# IR Diferido                                     -28029   -859414.016
# Participações/Contribuições Estatutárias           NaN           NaN
# Reversão dos Juros sobre Capital Próprio           NaN           NaN
# Part. de Acionistas Não Controladores          -152180   -120675.008
# Lucro/Prejuízo do Período                  2810662.912     4538393.6
#
# 0                                           30/09/2014    30/06/2014  \
# ABEV3
# Ativo Total                               65125920.768   62989045.76
# Ativo Circulante                          15446576.128  15773268.992
# Caixa e Equivalentes de Caixa              5748115.968   6273862.144
# Aplicações Financeiras                      526788.992    379937.984
# Contas a Receber                           3275641.088   3538383.872
# ...                                                ...           ...
# IR Diferido                                     475888         30916
# Participações/Contribuições Estatutárias           NaN           NaN
# Reversão dos Juros sobre Capital Próprio           NaN           NaN
# Part. de Acionistas Não Controladores           -76946        -48724
# Lucro/Prejuízo do Período                  2813597.952   2166882.048
#
# 0                                           31/03/2014    31/12/2013  \
# ABEV3
# Ativo Total                                63297044.48  68674015.232
# Ativo Circulante                          16352306.176  20470011.904
# Caixa e Equivalentes de Caixa              7296176.128  11285832.704
# Aplicações Financeiras                      410172.992        288604
# Contas a Receber                            3110085.12   3613506.048
# ...                                                ...           ...
# IR Diferido                                     403236   -197097.984
# Participações/Contribuições Estatutárias           NaN           NaN
# Reversão dos Juros sobre Capital Próprio           NaN           NaN
# Part. de Acionistas Não Controladores           -50162    -85133.056
# Lucro/Prejuízo do Período                  2546639.104    6093754.88
#
# 0                                           30/09/2013    30/06/2013  \
# ABEV3
# Ativo Total                               59618975.744  58739269.632
# Ativo Circulante                          12478373.888   12057052.16
# Caixa e Equivalentes de Caixa              4835169.792   4482174.976
# Aplicações Financeiras                      612489.024    486132.992
# Contas a Receber                           2747849.984   2783139.072
# ...                                                ...           ...
# IR Diferido                                    -462300        114066
# Participações/Contribuições Estatutárias           NaN           NaN
# Reversão dos Juros sobre Capital Próprio           NaN           NaN
# Part. de Acionistas Não Controladores           -49296   -758398.976
# Lucro/Prejuízo do Período                  2289705.984   1141740.032
#
# 0                                          31/03/2013   31/12/2012
# ABEV3
# Ativo Total                               1340374.016  1346301.056
# Ativo Circulante                                77552        71641
# Caixa e Equivalentes de Caixa                   74204        48155
# Aplicações Financeiras                              0            0
# Contas a Receber                                 3105        21490
# ...                                               ...          ...
# IR Diferido                                       -70          NaN
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores             NaN          NaN
# Lucro/Prejuízo do Período                        9768          NaN
#
# [79 rows x 33 columns]
# Empresa: B3SA3
# 0                                           31/12/2020    30/09/2020  \
# B3SA3
# Ativo Total                                46332784.64  45378408.448
# Ativo Circulante                          17101290.496  16127392.768
# Caixa e Equivalentes de Caixa              1438419.968   1290332.032
# Aplicações Financeiras                    14068886.528  13346030.592
# Contas a Receber                                412116    345904.992
# ...                                                ...           ...
# IR Diferido                                -267797.984   -274449.984
# Participações/Contribuições Estatutárias           NaN           NaN
# Reversão dos Juros sobre Capital Próprio           NaN           NaN
# Part. de Acionistas Não Controladores               41           488
# Lucro/Prejuízo do Período                  1097380.096   1136984.064
#
# 0                                           30/06/2020    31/03/2020  \
# B3SA3
# Ativo Total                               44192559.104  41141846.016
# Ativo Circulante                          15139864.576  11881339.904
# Caixa e Equivalentes de Caixa               966702.016        905064
# Aplicações Financeiras                    13071602.688  10070641.664
# Contas a Receber                            333665.984    312401.984
# ...                                                ...           ...
# IR Diferido                                    -126873        -62163
# Participações/Contribuições Estatutárias           NaN           NaN
# Reversão dos Juros sobre Capital Próprio           NaN           NaN
# Part. de Acionistas Não Controladores              629           431
# Lucro/Prejuízo do Período                   892387.968       1025552
#
# 0                                           31/12/2019    30/09/2019  \
# B3SA3
# Ativo Total                               40027316.224  40950870.016
# Ativo Circulante                          10469005.312  11509549.056
# Caixa e Equivalentes de Caixa               494032.992    642588.992
# Aplicações Financeiras                     8977000.448  10050922.496
# Contas a Receber                                339320    294647.008
# ...                                                ...           ...
# IR Diferido                                -143146.016        -55836
# Participações/Contribuições Estatutárias           NaN           NaN
# Reversão dos Juros sobre Capital Próprio           NaN           NaN
# Part. de Acionistas Não Controladores              438           224
# Lucro/Prejuízo do Período                    733368.96    719830.016
#
# 0                                           30/06/2019    31/03/2019  \
# B3SA3
# Ativo Total                               40174936.064  38714220.544
# Ativo Circulante                          10323038.208   8800334.848
# Caixa e Equivalentes de Caixa               520252.992    888531.008
# Aplicações Financeiras                     8968496.128   7149206.016
# Contas a Receber                                345388    317456.992
# ...                                                ...           ...
# IR Diferido                                    -109677       -123640
# Participações/Contribuições Estatutárias           NaN           NaN
# Reversão dos Juros sobre Capital Próprio           NaN           NaN
# Part. de Acionistas Não Controladores              219            81
# Lucro/Prejuízo do Período                   654769.024    606198.016
#
# 0                                          31/12/2018    30/09/2018  ...  \
# B3SA3                                                                ...
# Ativo Total                                37672243.2  38653591.552  ...
# ...
# IR Diferido                                     -3610        -9006
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores               0            0
# Lucro/Prejuízo do Período                      119066       110044
#
# 0                                          31/03/2019   31/12/2018  \
# QUAL3
# Ativo Total                               3756843.008  3549313.024
# Ativo Circulante                          1191261.056   981665.984
# Caixa e Equivalentes de Caixa                  262560       137446
# Aplicações Financeiras                     467623.008   352091.008
# Contas a Receber                               172752   192355.008
# ...                                               ...          ...
# IR Diferido                                     -6858        -1842
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores               0            0
# Lucro/Prejuízo do Período                       96888    96042.008
#
# 0                                          30/09/2018  30/06/2018  ...  \
# QUAL3                                                              ...
# Ativo Total                               3724770.048  3419127.04  ...
# Ativo Circulante                          1098036.992  954462.016  ...
# Caixa e Equivalentes de Caixa                  243730      108492  ...
# Aplicações Financeiras                     406012.992  360489.984  ...
# Contas a Receber                               200596      208378  ...
# ...                                               ...         ...  ...
# IR Diferido                                      1597      -25628  ...
# Participações/Contribuições Estatutárias          NaN         NaN  ...
# Reversão dos Juros sobre Capital Próprio          NaN         NaN  ...
# Part. de Acionistas Não Controladores               0           0  ...
# Lucro/Prejuízo do Período                      109723       88575  ...
#
# 0                                          31/03/2013   31/12/2012  \
# QUAL3
# Ativo Total                               3057185.024  3095250.944
# Ativo Circulante                           319928.992   279758.016
# Caixa e Equivalentes de Caixa              146939.008       123957
# Aplicações Financeiras                          19444        19144
# Contas a Receber                                93778        86995
# ...                                               ...          ...
# IR Diferido                                     -1793         2190
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores           -1965         -999
# Lucro/Prejuízo do Período                        7417       -14256
#
# 0                                          30/09/2012   30/06/2012  \
# QUAL3
# Ativo Total                               3085238.016  2850300.928
# Ativo Circulante                           242984.992       517236
# Caixa e Equivalentes de Caixa                   78189   321833.984
# Aplicações Financeiras                          17291        13717
# Contas a Receber                                80380        52032
# ...                                               ...          ...
# IR Diferido                                      -346       -10420
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores              39            6
# Lucro/Prejuízo do Período                       12707        13687
#
# 0                                          31/03/2012   31/12/2011  \
# QUAL3
# Ativo Total                               2821391.104  2855305.984
# Ativo Circulante                           457820.992   464699.008
# Caixa e Equivalentes de Caixa              359955.008       369668
# Aplicações Financeiras                          12555        12233
# Contas a Receber                                45136        49028
# ...                                               ...          ...
# IR Diferido                                     -8364        -5976
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores            -155         -177
# Lucro/Prejuízo do Período                       10139         8641
#
# 0                                          30/09/2011   30/06/2011  \
# QUAL3
# Ativo Total                               2761074.944  2591724.032
# Ativo Circulante                               390388   207611.008
# Caixa e Equivalentes de Caixa              308196.992   142543.008
# Aplicações Financeiras                          10926        10617
# Contas a Receber                                43447        33144
# ...                                               ...          ...
# IR Diferido                                     -9713        -6529
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores             -51            0
# Lucro/Prejuízo do Período                       12193       -48986
#
# 0                                          31/03/2011   31/12/2010
# QUAL3
# Ativo Total                               2462347.008  2453131.008
# Ativo Circulante                           209532.992   177391.008
# Caixa e Equivalentes de Caixa                  149162       139094
# Aplicações Financeiras                          10103         6521
# Contas a Receber                                46196        16085
# ...                                               ...          ...
# IR Diferido                                      9105          NaN
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores               0          NaN
# Lucro/Prejuízo do Período                       -5746          NaN
#
# [79 rows x 40 columns]
# Empresa: MULT3
# 0                                           31/12/2020    30/09/2020  \
# MULT3
# Ativo Total                               10564284.416  11137562.624
# Ativo Circulante                           1838108.032   2481417.984
# Caixa e Equivalentes de Caixa              1223414.016   1765917.056
# Aplicações Financeiras                               0         62131
# Contas a Receber                                501716    477807.008
# ...                                                ...           ...
# IR Diferido                                      65224        -27078
# Participações/Contribuições Estatutárias           NaN           NaN
# Reversão dos Juros sobre Capital Próprio           NaN           NaN
# Part. de Acionistas Não Controladores               46            58
# Lucro/Prejuízo do Período                       146862    568761.024
#
# 0                                           30/06/2020    31/03/2020  \
# MULT3
# Ativo Total                               10526478.336  10411515.904
# Ativo Circulante                           1632674.944   1490791.936
# Caixa e Equivalentes de Caixa               950745.024    990094.016
# Aplicações Financeiras                          142076    150708.992
# Contas a Receber                            361728.992        217370
# ...                                                ...           ...
# IR Diferido                                     -57678        -52884
# Participações/Contribuições Estatutárias           NaN           NaN
# Reversão dos Juros sobre Capital Próprio           NaN           NaN
# Part. de Acionistas Não Controladores               66            26
# Lucro/Prejuízo do Período                        70802    177748.992
#
# 0                                          31/12/2019   30/09/2019  \
# MULT3
# Ativo Total                               9576749.056   9454658.56
# Ativo Circulante                          1319294.976  1377394.048
# Caixa e Equivalentes de Caixa                   36463        38722
# Aplicações Financeiras                     871505.984   939710.976
# Contas a Receber                               284116   248240.992
# ...                                               ...          ...
# IR Diferido                                      3711        -3969
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores              42          544
# Lucro/Prejuízo do Período                  142288.016       121525
#
# 0                                          30/06/2019   31/03/2019  \
# MULT3
# Ativo Total                               9353537.536  9023955.968
# Ativo Circulante                           1327623.04   1370232.96
# Caixa e Equivalentes de Caixa                   31233        44148
# Aplicações Financeiras                     881859.968   961123.008
# Contas a Receber                               258808       234324
# ...                                               ...          ...
# IR Diferido                                     -1182        -3722
# Participações/Contribuições Estatutárias          NaN          NaN
# Reversão dos Juros sobre Capital Próprio          NaN          NaN
# Part. de Acionistas Não Controladores             602          615
# Lucro/Prejuízo do Período                      115239        91946
#
# 0                                          31/12/2018   30/09/2018  ...  \
# MULT3                                                               ...
# Ativo Total                               8875257.856  8819852.288  ...
# Ativo Circulante                          1274156.032  1243000.064  ...
# Caixa e Equivalentes de Caixa                   38864        49485  ...
# Aplicações Financeiras                     816905.024   792971.008  ...
# Contas a Receber                           284310.016   257599.008  ...
# ...                                               ...          ...  ...
# IR Diferido                                     -1459        -5335  ...
# Participações/Contribuições Estatutárias          NaN          NaN  ...
# Reversão dos Juros sobre Capital Próprio          NaN          NaN  ...
# Part. de Acionistas Não Controladores             640          586  ...
# Lucro/Prejuízo do Período                      112693       116445  ...
#
# 0                                          31/12/2012  30/09/2012  \
# MULT3
# Ativo Total                               5684511.744     5204608
# Ativo Circulante                           851337.984  708683.008
# Caixa e Equivalentes de Caixa              392856.992  322707.008
# Aplicações Financeiras                           2144        1523
# Contas a Receber                               219592      204170
# ...                                               ...         ...
# IR Diferido                                     -8340      -12862
# Participações/Contribuições Estatutárias          NaN         NaN
# Reversão dos Juros sobre Capital Próprio          NaN         NaN
# Part. de Acionistas Não Controladores             -23         -17
# Lucro/Prejuízo do Período                  128449.008       72012
#
# 0                                          30/06/2012  31/03/2012  \
# MULT3
# Ativo Total                               4910102.016  4844113.92
# Ativo Circulante                           785171.968  989990.976
# Caixa e Equivalentes de Caixa              444444.992  627150.016
# Aplicações Financeiras                           1493       27884
# Contas a Receber                           190304.992      177166
# ...                                               ...         ...
# IR Diferido                                    -13118      -18528
# Participações/Contribuições Estatutárias          NaN         NaN
# Reversão dos Juros sobre Capital Próprio          NaN         NaN
# Part. de Acionistas Não Controladores             -19       -1248
# Lucro/Prejuízo do Período                       63103      124491
#
# 0                                          31/12/2011  30/09/2011  \
# MULT3
# Ativo Total                               4703944.192  4229521.92
# Ativo Circulante                           978539.008  810502.976
# Caixa e Equivalentes de Caixa                  527392      532860
# Aplicações Financeiras                          30951           0
# Contas a Receber                               201024      179108
# ...                                               ...         ...
# IR Diferido                                     -7727      -19329
# Participações/Contribuições Estatutárias          NaN         NaN
# Reversão dos Juros sobre Capital Próprio          NaN         NaN
# Part. de Acionistas Não Controladores           -2674       -3329
# Lucro/Prejuízo do Período                      108114       65268
#
# 0                                          30/06/2011  31/03/2011  \
# MULT3
# Ativo Total                               4032890.112  4040855.04
# Ativo Circulante                           804582.016  997526.016
# Caixa e Equivalentes de Caixa              559467.008  784726.016
# Aplicações Financeiras                              0           0
# Contas a Receber                           168683.008      150708
# ...                                               ...         ...
# IR Diferido                                     -4798      -25017
# Participações/Contribuições Estatutárias          NaN         NaN
# Reversão dos Juros sobre Capital Próprio          NaN         NaN
# Part. de Acionistas Não Controladores           -2002       -2738
# Lucro/Prejuízo do Período                       61072       63722
#
# 0                                          31/12/2010   30/09/2010
# MULT3
# Ativo Total                               3985986.048   3907150.08
# Ativo Circulante                          1028182.976  1085554.048
# Caixa e Equivalentes de Caixa              794838.976   840118.016
# Aplicações Financeiras                              0            0
# Contas a Receber                               180122       174292
# ...                                               ...          ...
# IR Diferido                                    -21908       -26614
# Participações/Contribuições Estatutárias          NaN            0
# Reversão dos Juros sobre Capital Próprio          NaN            0
# Part. de Acionistas Não Controladores           -3247        -2583
# Lucro/Prejuízo do Período                   74601.008        45607
#
# [79 rows x 42 columns]

# %% [markdown]
# ### Pegar Preços das Ações nas Datas Correspondentes

# %%
cotacoes_df = pd.read_excel("Cotacoes.xlsx")
cotacoes = {}
for empresa in cotacoes_df["Empresa"].unique():
    cotacoes[empresa] = cotacoes_df.loc[cotacoes_df['Empresa']==empresa, :]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Documentos/learning_something/IA_actions/ia_carteira/lib/python3.12/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /usr/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 cotacoes_df = pd.read_excel("Cotacoes.xlsx")
#       2 cotacoes = {}
#       3 for empresa in cotacoes_df["Empresa"].unique():
#
# File ~/Documentos/learning_something/IA_actions/ia_carteira/lib/python3.12/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~/Documentos/learning_something/IA_actions/ia_carteira/lib/python3.12/site-packages/pandas/io/excel/_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1564 self.engine = engine
#    1565 self.storage_options = storage_options
# -> 1567 self._reader = self._engines[engine](
#    1568     self._io,
#    1569     storage_options=storage_options,
#    1570     engine_kwargs=engine_kwargs,
#    1571 )
#
# File ~/Documentos/learning_something/IA_actions/ia_carteira/lib/python3.12/site-packages/pandas/io/excel/_openpyxl.py:552, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     534 @doc(storage_options=_shared_docs["storage_options"])
#     535 def __init__(
#     536     self,
#    (...)
#     539     engine_kwargs: dict | None = None,
#     540 ) -> None:
#     541     """
#     542     Reader using openpyxl engine.
#     543
#    (...)
#     550         Arbitrary keyword arguments passed to excel engine.
#     551     """
# --> 552     import_optional_dependency("openpyxl")
#     553     super().__init__(
#     554         filepath_or_buffer,
#     555         storage_options=storage_options,
#     556         engine_kwargs=engine_kwargs,
#     557     )
#
# File ~/Documentos/learning_something/IA_actions/ia_carteira/lib/python3.12/site-packages/pandas/compat/_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %% [markdown]
# ### Remover empresas que tem cotações vazias da análise (mesmo após o tratamento que fizemos na hora de pegar as cotações)

# %% [markdown]
# ### Juntar fundamentos com Preço da Ação

# %% [markdown]
# ### Tratar colunas
#
# 1. Vamos pegar apenas empresas que possuem as mesmas colunas
# 2. Ajeitar colunas com nome repetido
# 3. Analisar valores vazios nas colunas

# %% [markdown]
# #### 1. Remover da análise colunas que não existem em alguma tabela

# %% [markdown]
# ####  2. Ajeitando colunas com o mesmo nome

# %% [markdown]
# #### 3. Analisar valores vazios nas colunas

# %% [markdown]
# ### Criando os rótulos: Comprar, Não Comprar ou Vender?
#
# Não queremos saber quando vender, mas inclui essa categoria para conseguir identificar quando que o nosso modelo vai sugerir uma compra quando na verdade o melhor momento era vender. Isso significa que o modelo errou "mais" do que quando sugeriu comprar e simplesmente o certo era não comprar
#
# Regra:
# 1. Subiu mais do que o Ibovespa (ou caiu menos) -> Comprar (Valor = 2)
# 2. Subiu menos do que o Ibovespa até Ibovespa - 2% (ou caiu mais do que Ibovespa até Ibovespa -2%) -> Não Comprar (Valor = 1)
# 3. Subiu menos do que o Ibovespa - 2% (ou caiu mais do que Ibovespa -2%) -> Vender (Valor = 0)

# %% [markdown]
# ### Hora de tornar tudo 1 dataframe só

# %% [markdown]
# ### Análise Exploratória

# %% [markdown]
# #### 1. Quantidade de Respostas em cada Tipo de Decisão

# %% [markdown]
# #### 2. Correlação

# %% [markdown]
# #### Vamos remover Todas as Colunas "já explicadas" pelo Ativo Total

# %% [markdown]
# ### Vamos partir para Feature Selection
#
# Será que todas essas features são importantes mesmo para o nosso modelo? Muitas features nem sempre é bom, se pudermos reduzir sem perder eficiência do nosso modelo, melhor
#
# Aqui temos 2 alternativas:
#
# 1. Seguir com todas as features e depois tentar melhorar o nosso modelo
# 2. Usar algum critério para selecionar as melhores features para prever e criar o modelo a partir apenas dessa seleção menor de features
#
# Vou seguir com a opção 2, porque é mais rápida e, caso dê certo, facilita a nossa vida. Se der errado, a gente volta aqui e refaz o processo

# %% [markdown]
# ### Aplicação do StandardScaler para melhorar nossos modelos de MachineLearning

# %% [markdown]
# ### Separação dos dados em treino e teste

# %% [markdown]
# ### Criação de um Dummy Classifier (Uma baseline para ver se os nossos modelos são melhores do que puro chute)

# %% [markdown]
# ### Métricas de Avaliação
#
# - Precisão vai ser nossa métrica principal
# - Recall pode ser útil, mas precisão no caso de ações é mt mais importante.
#
# Explicação: Foto dos Gatos e Cachorros na Wikipedia: https://en.wikipedia.org/wiki/Precision_and_recall

# %% [markdown]
# ### Modelos que vamos testar
# - AdaBoost
# - Decision Tree
# - Random Forest
# - ExtraTree
# - Gradient Boost
# - K Nearest Neighbors (KNN)
# - Logistic Regression
# - Naive Bayes
# - Support Vector Machine (SVM)
# - Rede Neural

# %% [markdown]
# ### Agora vamos ao tunning do modelo
#
# - é bom sempre incluir no tuning os parâmetros "padrões" do modelo, se não poder ser que vc só encontre resultados piores

# %% [markdown]
# ### Vamos seguir então com o Modelo BLA tunado para ser o nosso modelo
#
# - Agora ao que interessa...será que vamos conseguir escolher boas ações e ter uma carteira rentável?
# - Para isso, temos que pegar o último Trimestre (que não usamos para treinar o modelo nem testar) e ver como ele teria saído até o momento em que gravo esse vídeo...

# %% [markdown]
# ### Repetindo os passos com a base fundamentos só que pegando apenas o último tri de cada empresa

# %% [markdown]
# ### Agora fazemos a previsão de decisões
